# %%
from qiskit import *
from qiskit.visualization import plot_histogram
from qiskit.tools.monitor import job_monitor

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Plot histogram

# %%
# quantum circuit to make a Bell state
bell = QuantumCircuit(2, 2)
bell.h(0)
bell.cx(0, 1)

meas = QuantumCircuit(2, 2)
meas.measure([0,1], [0,1])

# execute the quantum circuit
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
circ = bell + meas
result = execute(circ, backend, shots=30000).result()
counts  = result.get_counts(circ)
print(counts)
# Out:
# {'11': 14738, '00': 15262}

# %%
plot_histogram(counts)

# %%
# Execute 2-qubit Bell state again
second_result = execute(circ, backend, shots=30000).result()
second_counts  = second_result.get_counts(circ)
# Plot results with legend
legend = ['First execution', 'Second execution']
plot_histogram([counts, second_counts], legend=legend)

# %%
plot_histogram([counts, second_counts], legend=legend, sort='desc', figsize=(15,12),
               color=['orange', 'black'], bar_labels=False)

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Plot histogram

# %%
from qiskit.visualization import plot_state_city, plot_bloch_multivector
from qiskit.visualization import plot_state_paulivec, plot_state_hinton
from qiskit.visualization import plot_state_qsphere

# %%
# execute the quantum circuit
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(bell, backend).result()
psi  = result.get_statevector(bell)

# %%
plot_state_city(psi, figsize=(20,10))

# %%
plot_state_hinton(psi, figsize=(16,8))

# %%
plot_state_qsphere(psi, figsize=(10,10))

# %%
plot_state_paulivec(psi, figsize=(10,10))

# %%
plot_bloch_multivector(psi, figsize=(20,20))

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Options when using state plotting functions

# %%
plot_state_city(psi, title="My City", color=['black', 'orange'], figsize=(20,10))

# %%
plot_state_hinton(psi, title="My Hinton", figsize=(10,10))

# %%
plot_state_paulivec(psi, title="My Paulivec", color=['purple', 'orange', 'green'], figsize=(10,10))

# %%
plot_bloch_multivector(psi, title="My Bloch Spheres", figsize=(10,10))

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Interactive State Plots for Jupyter Notebooks

# %%
from qiskit.tools.visualization import iplot_state_paulivec

# %%
# Generate an interactive pauli vector plot
iplot_state_paulivec(psi)
# Out:
# /home/miguel/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The iplot_state_paulivec function is deprecated and will be removed in a future release. The hosted code this depended on no longer exists so this is falling back to use the matplotlib visualizations. qiskit.visualization.plot_state_paulivec should be used directly moving forward.

# %% [markdown]
# <br>
# <br>
# <br>
#
# # Plot Bloch Vector

# %%
from qiskit.visualization import plot_bloch_vector

# %%
plot_bloch_vector([0,1,0])

# %%
plot_bloch_vector([0,1,0], title='My Bloch Sphere', figsize=(10,10))
